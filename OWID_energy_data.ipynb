# %% [markdown]
#                                         OWID_ENERGY_DATA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("owid-energy-data.csv")

# %%
print(df['year'].unique())
# Out:
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 1900 1901
#  1902 1903 1904 1905 1906 1907 1908 1909 1910 1911 1912 1913 1914 1915
#  1916 1917 1918 1919 1920 1921 1922 1923 1924 1925 1926 1927 1928 1929
#  1930 1931 1932 1933 1934 1935 1936 1937 1938 1939 1940 1941 1942 1943
#  1944 1945 1946 1947 1948 1949 1950 1951 1952 1953 1954 1955 1956 1957
#  1958 1959 1960 1961 1962 1963 1964 1965 1966 1967 1968 1969 1970 1971
#  1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1982 1983 1984 1985
#  1986 1987 1988 1989 1990 1991 1992 1993 1994 1995 1996 1997 1998 1999]

# %%
df=df[df['year']>=2000]

# %%
print(df['year'].min())
# Out:
# 2000

# %%
df.head()
# Out:
#          country  year iso_code  population  gdp  biofuel_cons_change_pct  \
# 0  ASEAN (Ember)  2000      NaN         NaN  NaN                      NaN
# 1  ASEAN (Ember)  2001      NaN         NaN  NaN                      NaN
# 2  ASEAN (Ember)  2002      NaN         NaN  NaN                      NaN
# 3  ASEAN (Ember)  2003      NaN         NaN  NaN                      NaN
# 4  ASEAN (Ember)  2004      NaN         NaN  NaN                      NaN
#
#    biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    biofuel_elec_per_capita  ...  solar_share_elec  solar_share_energy  \
# ...

# %%
df=df.drop(columns=['iso_code'])

# %%
df['population']=df.groupby('country')['population'].ffill().bfill()

# %%
df.head()
# Out:
#          country  year  population  gdp  biofuel_cons_change_pct  \
# 0  ASEAN (Ember)  2000  20130334.0  NaN                      NaN
# 1  ASEAN (Ember)  2001  20130334.0  NaN                      NaN
# 2  ASEAN (Ember)  2002  20130334.0  NaN                      NaN
# 3  ASEAN (Ember)  2003  20130334.0  NaN                      NaN
# 4  ASEAN (Ember)  2004  20130334.0  NaN                      NaN
#
#    biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    biofuel_elec_per_capita  biofuel_electricity  ...  solar_share_elec  \
# ...

# %%
df.head()
# Out:
#          country  year  population  gdp  biofuel_cons_change_pct  \
# 0  ASEAN (Ember)  2000  20130334.0  NaN                      NaN
# 1  ASEAN (Ember)  2001  20130334.0  NaN                      NaN
# 2  ASEAN (Ember)  2002  20130334.0  NaN                      NaN
# 3  ASEAN (Ember)  2003  20130334.0  NaN                      NaN
# 4  ASEAN (Ember)  2004  20130334.0  NaN                      NaN
#
#    biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    biofuel_elec_per_capita  biofuel_electricity  ...  solar_share_elec  \
# ...

# %%
df['gdp']=df.groupby ('country')['gdp'].ffill().bfill()

# %%
df.head()
# Out:
#          country  year  population           gdp  biofuel_cons_change_pct  \
# 0  ASEAN (Ember)  2000  20130334.0  1.128379e+10                      NaN
# 1  ASEAN (Ember)  2001  20130334.0  1.128379e+10                      NaN
# 2  ASEAN (Ember)  2002  20130334.0  1.128379e+10                      NaN
# 3  ASEAN (Ember)  2003  20130334.0  1.128379e+10                      NaN
# 4  ASEAN (Ember)  2004  20130334.0  1.128379e+10                      NaN
#
#    biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    biofuel_elec_per_capita  biofuel_electricity  ...  solar_share_elec  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7636 entries, 0 to 23376
# Columns: 129 entries, country to wind_share_energy
# dtypes: float64(127), int64(1), object(1)
# memory usage: 7.6+ MB

# %%
df['biofuel']=df.groupby('country')['biofuel_cons_change_pct'].ffill().bfill()

# %%
df.describe()
# Out:
#               year    population           gdp  biofuel_cons_change_pct  \
# count  7636.000000  7.636000e+03  7.636000e+03              1682.000000
# mean   2012.001572  1.230158e+08  1.613503e+12                49.661815
# std       7.261077  5.571720e+08  9.214727e+12               316.918960
# min    2000.000000  1.776000e+03  3.128536e+08              -100.000000
# 25%    2006.000000  1.354145e+06  2.352573e+10                -1.255000
# 50%    2012.000000  8.921690e+06  6.880463e+10                 7.485000
# 75%    2018.000000  3.454413e+07  3.560720e+11                25.805750
# max    2025.000000  8.231613e+09  1.301130e+14              6373.062000
#
#        biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# count              3650.000000              2907.000000          3658.000000
# mean                  2.073870               113.931875            29.849372
# std                   9.563878               250.900441           109.955003
# ...

# %%
df=df.drop(columns=['biofuel_cons_change_twh'])

# %%
df.head()
# Out:
#          country  year  population           gdp  biofuel_cons_change_pct  \
# 0  ASEAN (Ember)  2000  20130334.0  1.128379e+10                      NaN
# 1  ASEAN (Ember)  2001  20130334.0  1.128379e+10                      NaN
# 2  ASEAN (Ember)  2002  20130334.0  1.128379e+10                      NaN
# 3  ASEAN (Ember)  2003  20130334.0  1.128379e+10                      NaN
# 4  ASEAN (Ember)  2004  20130334.0  1.128379e+10                      NaN
#
#    biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 0                      NaN                  NaN                      NaN
# 1                      NaN                  NaN                      NaN
# 2                      NaN                  NaN                      NaN
# 3                      NaN                  NaN                      NaN
# 4                      NaN                  NaN                      NaN
#
#    biofuel_electricity  biofuel_share_elec  ...  solar_share_energy  \
# ...

# %%
df=df.drop(columns=['wind_cons_change_twh'])

# %%
df=df.drop(columns=['nuclear_cons_change_twh'])

# %%
df=df.drop(columns=['renewables_cons_change_twh'])

# %%
df=df.drop(columns=['oil_cons_change_twh'])

# %%
df=df.drop(columns=['gas_cons_change_twh'])

# %%
df=df.drop(columns=['coal_cons_change_twh'])

# %%
df=df.drop(columns=['low_carbon_cons_change_twh'])

# %%
df=df.drop(columns=['hydro_cons_change_twh'])

# %%
df=df.drop(columns=['other_renewables_cons_change_twh'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7636 entries, 0 to 23376
# Columns: 120 entries, country to biofuel
# dtypes: float64(118), int64(1), object(1)
# memory usage: 7.0+ MB

# %%
df.shape
# Out:
# (7636, 120)

# %%
df['biofuel']=df.groupby('country')['biofuel_cons_change_pct'].ffill().bfill()

# %%
df['biofuel']=df.groupby('country')['biofuel_cons_per_capita'].ffill().bfill()

# %%
df['biofuel']=df.groupby('country')['biofuel_consumption'].ffill().bfill()

# %%
df['biofuel']=df.groupby('country')['biofuel_elec_per_capita'].ffill().bfill()

# %%
df['biofuel']=df.groupby('country')['biofuel_electricity'].ffill().bfill()

# %%
df['biofuel']=df.groupby('country')['biofuel_share_elec'].ffill().bfill()

# %%
df.head()
# Out:
#          country  year  population           gdp  biofuel_cons_change_pct  \
# 0  ASEAN (Ember)  2000  20130334.0  1.128379e+10                      NaN
# 1  ASEAN (Ember)  2001  20130334.0  1.128379e+10                      NaN
# 2  ASEAN (Ember)  2002  20130334.0  1.128379e+10                      NaN
# 3  ASEAN (Ember)  2003  20130334.0  1.128379e+10                      NaN
# 4  ASEAN (Ember)  2004  20130334.0  1.128379e+10                      NaN
#
#    biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 0                      NaN                  NaN                      NaN
# 1                      NaN                  NaN                      NaN
# 2                      NaN                  NaN                      NaN
# 3                      NaN                  NaN                      NaN
# 4                      NaN                  NaN                      NaN
#
#    biofuel_electricity  biofuel_share_elec  ...  solar_share_elec  \
# ...

# %%
df.tail()
# Out:
#         country  year  population           gdp  biofuel_cons_change_pct  \
# 23372  Zimbabwe  2020  15526887.0  2.317871e+10                      NaN
# 23373  Zimbabwe  2021  15797220.0  2.514009e+10                      NaN
# 23374  Zimbabwe  2022  16069061.0  2.590159e+10                      NaN
# 23375  Zimbabwe  2023  16340829.0  2.590159e+10                      NaN
# 23376  Zimbabwe  2024  16634366.0  2.590159e+10                      NaN
#
#        biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 23372                      0.0                  0.0                    6.440
# 23373                      0.0                  0.0                    6.963
# 23374                      0.0                  0.0                    6.845
# 23375                      0.0                  0.0                    7.344
# 23376                      0.0                  0.0                    7.214
#
# ...

# %%
print(df.columns)
# Out:
# Index(['country', 'year', 'population', 'gdp', 'biofuel_cons_change_pct',
#        'biofuel_cons_per_capita', 'biofuel_consumption',
#        'biofuel_elec_per_capita', 'biofuel_electricity', 'biofuel_share_elec',
#        ...
#        'solar_share_elec', 'solar_share_energy', 'wind_cons_change_pct',
#        'wind_consumption', 'wind_elec_per_capita', 'wind_electricity',
#        'wind_energy_per_capita', 'wind_share_elec', 'wind_share_energy',
#        'biofuel'],
#       dtype='object', length=120)

# %%
null_count=df['biofuel_cons_change_pct'].isnull().sum()
print(null_count)
# Out:
# 5954

# %%
df=df.drop(columns=['solar_cons_change_pct'])

# %%
df=df.drop(columns=['wind_cons_change_pct'])

# %%
df=df.drop(columns=['nuclear_cons_change_pct'])

# %%
df=df.drop(columns=['oil_cons_change_pct'])

# %%
df=df.drop(columns=['gas_cons_change_pct'])

# %%
df=df.drop(columns=['coal_cons_change_pct'])

# %%
df=df.drop(columns=['low_carbon_cons_change_pct'])

# %%
df=df.drop(columns=['hydro_cons_change_pct'])

# %%
df=df.drop(columns=['renewables_cons_change_pct'])

# %%
df=df.drop(columns=['other_renewables_cons_change_pct'])

# %%
df=df.drop(columns=['biofuel_cons_change_pct'])

# %%
df.shape
# Out:
# (7636, 109)

# %%
df.head()
# Out:
#          country  year  population           gdp  biofuel_cons_per_capita  \
# 0  ASEAN (Ember)  2000  20130334.0  1.128379e+10                      NaN
# 1  ASEAN (Ember)  2001  20130334.0  1.128379e+10                      NaN
# 2  ASEAN (Ember)  2002  20130334.0  1.128379e+10                      NaN
# 3  ASEAN (Ember)  2003  20130334.0  1.128379e+10                      NaN
# 4  ASEAN (Ember)  2004  20130334.0  1.128379e+10                      NaN
#
#    biofuel_consumption  biofuel_elec_per_capita  biofuel_electricity  \
# 0                  NaN                      NaN                 5.87
# 1                  NaN                      NaN                 6.46
# 2                  NaN                      NaN                 6.62
# 3                  NaN                      NaN                 7.44
# 4                  NaN                      NaN                 8.39
#
#    biofuel_share_elec  biofuel_share_energy  ...  solar_energy_per_capita  \
# ...

# %%
df=df.drop(columns=['biofuel_share_energy'])

# %%
df=df.drop(columns=['wind_share_energy'])

# %%
df=df.drop(columns=['coal_share_energy'])

# %%
df=df.drop(columns=['gas_share_energy'])

# %%
df=df.drop(columns=['oil_share_energy'])

# %%
df=df.drop(columns=['renewables_share_energy'])

# %%
df=df.drop(columns=['hydro_share_energy'])

# %%
df=df.drop(columns=['nuclear_share_energy'])

# %%
df=df.drop(columns=['low_carbon_share_energy'])

# %%
df=df.drop(columns=['other_renewables_share_energy'])

# %%
df=df.drop(columns=['biofuel_elec_per_capita'])

# %%
df=df.drop(columns=['solar_elec_per_capita'])

# %%
df=df.drop(columns=['wind_elec_per_capita'])

# %%
df=df.drop(columns=['coal_elec_per_capita'])

# %%
df=df.drop(columns=['renewables_elec_per_capita'])

# %%
df=df.drop(columns=['low_carbon_elec_per_capita'])

# %%
df=df.drop(columns=['nuclear_elec_per_capita'])

# %%
df=df.drop(columns=['hydro_elec_per_capita'])

# %%
df=df.drop(columns=['gas_elec_per_capita'])

# %%
df=df.drop(columns=['oil_elec_per_capita'])

# %%
df.shape
# Out:
# (7636, 89)

# %%
df.to_csv('cleaned_data.csv',index=False)

# %%
df['biofuel']=df.groupby('country')['biofuel_cons_per_capita'].ffill().bfill()

# %%
df['biofuel']=df.groupby('country')['biofuel_consumption'].ffill().bfill()

# %%
df['biofuel']=df.groupby('country')['biofuel_electricity'].ffill().bfill()

# %%
df['biofuel']=df.groupby('country')['biofuel_share_elec'].ffill().bfill()

# %%
df['coal']=df.groupby('country')['coal_consumption'].ffill().bfill()
df['coal']=df.groupby('country')['coal_cons_per_capita'].ffill().bfill()
df['coal']=df.groupby('country')['coal_electricity'].ffill().bfill()
df['coal']=df.groupby('country')['coal_share_elec'].ffill().bfill()

# %%
df['oil']=df.groupby('country')['oil_consumption'].ffill().bfill()
df['oil']=df.groupby('country')['oil_electricity'].ffill().bfill()
df['oil']=df.groupby('country')['oil_share_elec'].ffill().bfill()

# %%
df['gas']=df.groupby('country')['gas_consumption'].ffill().bfill()
df['gas']=df.groupby('country')['gas_electricity'].ffill().bfill()
df['gas']=df.groupby('country')['gas_share_elec'].ffill().bfill()

# %%
df['renewables']=df.groupby('country')['renewables_consumption'].ffill().bfill()
df['renewables']=df.groupby('country')['renewables_electricity'].ffill().bfill()
df['renewables']=df.groupby('country')['renewables_share_elec'].ffill().bfill()

# %%
df['solar']=df.groupby('country')['solar_consumption'].ffill().bfill()
df['solar']=df.groupby('country')['solar_electricity'].ffill().bfill()
df['solar']=df.groupby('country')['solar_share_elec'].ffill().bfill()

# %%
df['wind']=df.groupby('country')['wind_consumption'].ffill().bfill()
df['wind']=df.groupby('country')['wind_electricity'].ffill().bfill()
df['wind']=df.groupby('country')['wind_share_elec'].ffill().bfill()

# %%
df['nuclear']=df.groupby('country')['nuclear_consumption'].ffill().bfill()
df['nuclear']=df.groupby('country')['nuclear_electricity'].ffill().bfill()
df['nuclear']=df.groupby('country')['nuclear_share_elec'].ffill().bfill()

# %%
df['hydro']=df.groupby('country')['hydro_consumption'].ffill().bfill()
df['hydro']=df.groupby('country')['hydro_electricity'].ffill().bfill()
df['hydro']=df.groupby('country')['hydro_share_elec'].ffill().bfill()

# %%
df.shape
# Out:
# (7636, 97)

# %%
total_nan_count=df.isna().sum().sum()
print(total_nan_count)
# Out:
# 258736

# %%
nan_counts=df.isna().sum()
print(nan_counts[nan_counts>0])
# Out:
# biofuel_cons_per_capita    4729
# biofuel_consumption        3978
# biofuel_electricity        1649
# biofuel_share_elec         1675
# carbon_intensity_elec      1634
#                            ...
# solar_share_energy         4861
# wind_consumption           4861
# wind_electricity           1509
# wind_energy_per_capita     5386
# wind_share_elec            1535
# Length: 84, dtype: int64

# %%
df.fillna(0,inplace=True)

# %%
print(df.isna().sum().sum())
# Out:
# 0

# %%
df['year']=pd.to_datetime(df['year'],format='%Y')

# %%
print(df['year'].dtype)
# Out:
# datetime64[ns]

# %% [markdown]
# ### TIMESERIES FORECASTING (Fb PROPHET MODEL)

# %%
import numpy as np
from prophet import Prophet

   ###  Load data
df = pd.read_csv('cleaned_data.csv')

   ### Handling columns
country_col = 'country' if 'country' in df.columns else 'entity'
df = df.rename(columns={'year': 'ds', country_col: 'entity'})
df['ds'] = pd.to_datetime(df['ds'], format='%Y')

target_column = 'low_carbon_share_elec' 
target_goal_percentage = 100.0
forecast_horizon_years = 30

results = []

for country_name in df['entity'].unique():
    cdf = df[df['entity'] == country_name][['ds', target_column]].dropna().copy()
    cdf = cdf.rename(columns={target_column: 'y'})
    
    if len(cdf) < 5:
        continue
        
    cdf['cap'] = 100.0
    m = Prophet(growth='logistic', yearly_seasonality=False, weekly_seasonality=False, daily_seasonality=False)
    m.fit(cdf)
    
    
    future = m.make_future_dataframe(periods=30, freq='YE')
    future['cap'] = 100.0
    forecast = m.predict(future)
    
    
    attained_rows = forecast[forecast['yhat'] >= target_goal_percentage]
    attained_year = int(attained_rows.iloc[0]['ds'].year) if not attained_rows.empty else np.nan

    
    
    start_val = forecast.iloc[0]['yhat']
    end_val = forecast.iloc[-1]['yhat']
    total_growth_pct = ((end_val - start_val) / max(start_val, 1e-5)) * 100
    
    results.append({
        'country': country_name,
        'target_attained_year': attained_year,
        'projected_final_percentage': round(end_val, 2),
        'total_percentage_growth': round(total_growth_pct, 2)
    })

results_df = pd.DataFrame(results)

print(results_df.sort_values(by='target_attained_year', na_position='last'))
# Out:
# 11:54:16 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:16 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:16 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:16 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:17 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:17 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:17 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:17 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:18 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:18 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:18 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:18 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:19 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:19 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:19 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:19 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:20 - cmdstanpy - INFO - Chain [1] start processing
# ...

# %%
results_df.to_csv('clean_energy_forecast_summary.csv',index=False)
print("summary results saved sucessfully!")
# Out:
# summary results saved sucessfully!

# %% [markdown]
# ### Plotting forecast for a specific country

# %%
import matplotlib.pyplot as plt


selected_country = 'India' 


cdf = df[df['entity'] == selected_country][['ds', 'low_carbon_share_elec']].dropna()
cdf = cdf.rename(columns={'low_carbon_share_elec': 'y'})
cdf['cap'] = 100.0

m = Prophet(growth='logistic', yearly_seasonality=False, weekly_seasonality=False, daily_seasonality=False)
m.fit(cdf)

future = m.make_future_dataframe(periods=30, freq='YE')
future['cap'] = 100.0
forecast = m.predict(future)

fig = m.plot(forecast)
plt.title(f'Clean Energy Share Forecast for {selected_country}')
plt.xlabel('Year')
plt.ylabel('Low Carbon Share of Electricity (%)')
plt.show()

fig_comp = m.plot_components(forecast)
plt.show()
# Out:
# 11:57:35 - cmdstanpy - INFO - Chain [1] start processing
# 11:57:35 - cmdstanpy - INFO - Chain [1] done processing

# %%
print(cdf.info())
print(cdf.head())

# %%
print("original df shape:",df.shape)
# Out:
# original df shape: (7636, 89)

# %%
print(df.columns.tolist())
# Out:
# ['entity', 'ds', 'population', 'gdp', 'biofuel_cons_per_capita', 'biofuel_consumption', 'biofuel_electricity', 'biofuel_share_elec', 'carbon_intensity_elec', 'coal_cons_per_capita', 'coal_consumption', 'coal_electricity', 'coal_prod_change_pct', 'coal_prod_change_twh', 'coal_prod_per_capita', 'coal_production', 'coal_share_elec', 'electricity_demand', 'electricity_demand_per_capita', 'electricity_generation', 'electricity_share_energy', 'energy_cons_change_pct', 'energy_cons_change_twh', 'energy_per_capita', 'energy_per_gdp', 'fossil_cons_change_pct', 'fossil_cons_change_twh', 'fossil_elec_per_capita', 'fossil_electricity', 'fossil_energy_per_capita', 'fossil_fuel_consumption', 'fossil_share_elec', 'fossil_share_energy', 'gas_consumption', 'gas_electricity', 'gas_energy_per_capita', 'gas_prod_change_pct', 'gas_prod_change_twh', 'gas_prod_per_capita', 'gas_production', 'gas_share_elec', 'greenhouse_gas_emissions', 'hydro_consumption', 'hydro_electricity', 'hydro_energy_per_capita', 'h
# ...

# %%
for country_name in ['China','United States']:
    temp_df=df[df['entity']==country_name]
    print(f"{country_name}rows:{temp_df.shape[0]}")
    print(temp_df[['ds','entity']].dropna().shape[0])
# Out:
# Chinarows:26
# 26
# United Statesrows:26
# 26

# %% [markdown]
# ## checking metric column

# %%
for country_name in ['China','United States']:
    temp_df=df[df['entity']==country_name]
    valid_y_rows=temp_df[['ds','low_carbon_share_elec']].dropna().shape[0]
    print(f"{country_name}valid metric rows: {valid_y_rows}")
# Out:
# Chinavalid metric rows: 26
# United Statesvalid metric rows: 26

# %%
for country_name in ['India','China','United States']:
    cdf=df[df['entity']==country_name].copy()
    cdf=cdf[['ds','low_carbon_share_elec']].rename(columns={'low_carbon_share_elec':'y'})
    cdf=cdf.dropna()
    cdf['cap']=100.0
    m=Prophet(growth='logistic',yearly_seasonality=False,weekly_seasonality=False,daily_seasonality=False)
    m.fit(cdf)
# Out:
# 16:30:40 - cmdstanpy - INFO - Chain [1] start processing
# 16:30:40 - cmdstanpy - INFO - Chain [1] done processing
# 16:30:41 - cmdstanpy - INFO - Chain [1] start processing
# 16:30:41 - cmdstanpy - INFO - Chain [1] done processing
# 16:30:41 - cmdstanpy - INFO - Chain [1] start processing
# 16:30:41 - cmdstanpy - INFO - Chain [1] done processing

# %%
selected_country = 'United States' 


cdf = df[df['entity'] == selected_country][['ds', 'low_carbon_share_elec']].dropna()
cdf = cdf.rename(columns={'low_carbon_share_elec': 'y'})
cdf['cap'] = 100.0

m = Prophet(growth='logistic', yearly_seasonality=False, weekly_seasonality=False, daily_seasonality=False)
m.fit(cdf)

future = m.make_future_dataframe(periods=30, freq='YE')
future['cap'] = 100.0
forecast = m.predict(future)

fig = m.plot(forecast)
plt.title(f'Clean Energy Share Forecast for {selected_country}')
plt.xlabel('Year')
plt.ylabel('Low Carbon Share of Electricity (%)')
plt.show()

fig_comp = m.plot_components(forecast)
plt.show()
# Out:
# 16:32:13 - cmdstanpy - INFO - Chain [1] start processing
# 16:32:13 - cmdstanpy - INFO - Chain [1] done processing

# %%
selected_country = 'China' 


cdf = df[df['entity'] == selected_country][['ds', 'low_carbon_share_elec']].dropna()
cdf = cdf.rename(columns={'low_carbon_share_elec': 'y'})
cdf['cap'] = 100.0

m = Prophet(growth='logistic', yearly_seasonality=False, weekly_seasonality=False, daily_seasonality=False)
m.fit(cdf)

future = m.make_future_dataframe(periods=30, freq='YE')
future['cap'] = 100.0
forecast = m.predict(future)

fig = m.plot(forecast)
plt.title(f'Clean Energy Share Forecast for {selected_country}')
plt.xlabel('Year')
plt.ylabel('Low Carbon Share of Electricity (%)')
plt.show()

fig_comp = m.plot_components(forecast)
plt.show()
# Out:
# 16:32:30 - cmdstanpy - INFO - Chain [1] start processing
# 16:32:30 - cmdstanpy - INFO - Chain [1] done processing

# %%
target_year = 2050
target_share = 100.0

results = []

for country_name in ['India', 'China', 'United States']:

    
    # Filtering  data for the country and drop missing values for the metric
    temp_df = df[df['entity'] == country_name][['ds', 'low_carbon_share_elec']].dropna()
    
    
    if not temp_df.empty:
        
        latest_row = temp_df.loc[temp_df['ds'].idxmax()]
        latest_year = latest_row['ds'].year
        latest_share = latest_row['low_carbon_share_elec']
        
        # Calculate time remaining
        years_remaining = target_year - latest_year
        
        if years_remaining > 0 and latest_share < target_share:
            # Absolute growth rate (percentage points needed per year)
            points_per_year = (target_share - latest_share) / years_remaining
            
            # Compound Annual Growth Rate (CAGR)
            cagr = ((target_share / latest_share) ** (1 / years_remaining) - 1) * 100
            
            results.append({
                'Country': country_name,
                'Latest Year': latest_year,
                'Latest Share (%)': round(latest_share, 2),
                'Points Needed/Year': round(points_per_year, 2),
                'CAGR (%)': round(cagr, 2)
            })

# Converting results into a DataFrame 
import pandas as pd
growth_df = pd.DataFrame(results)
print(growth_df.to_string(index=False))
# Out:
#       Country  Latest Year  Latest Share (%)  Points Needed/Year  CAGR (%)
#         India         2025             26.65                2.93      5.43
#         China         2025             41.65                2.33      3.57
# United States         2025             43.00                2.28      3.43

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

plt.figure(figsize=(10, 6))


sns.lineplot(
    data=temp_df, 
    x='ds', 
    y='low_carbon_share_elec', 
    marker='o', 
    linewidth=2.5, 
    color='teal'
)

plt.title('Low Carbon Electricity Share Growth Over Time', fontsize=14, fontweight='bold')
plt.xlabel('Year / Date', fontsize=12)
plt.ylabel('Low Carbon Share (%)', fontsize=12)


plt.tight_layout()
plt.show()

# %%
import pandas as pd
from prophet import Prophet

all_forecasts = []

for country_name in ['India', 'China', 'United States']:
    
    cdf = df[df['entity'] == country_name].copy()
    cdf = cdf[['ds', 'low_carbon_share_elec']].rename(columns={'low_carbon_share_elec': 'y'})
    cdf = cdf.dropna()
    cdf['cap'] = 100.0
    
    # Fitting Prophet model
    m = Prophet(growth='logistic', yearly_seasonality=False, weekly_seasonality=False, daily_seasonality=False)
    m.fit(cdf)
    
    # 3. Creating  future dataframe up to 2050
    future = m.make_future_dataframe(periods=25, freq='YS')
    future['cap'] = 100.0
    
    # 4. Prediction
    forecast = m.predict(future)
    
    
    expanded_forecast = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper', 'trend']].copy()
    
    expanded_forecast['entity'] = country_name
    
    expanded_forecast = pd.merge(expanded_forecast, cdf, on='ds', how='left')
    
    all_forecasts.append(expanded_forecast)

# Combine all countries into one master DataFrame for tableau visuaization
master_forecast_df = pd.concat(all_forecasts, ignore_index=True)

# Save to CSV for Tableau
master_forecast_df.to_csv('clean_energy_master_forecast.csv', index=False)
print("Master forecast file successfully created and ready for Tableau!")
# Out:
# 16:49:22 - cmdstanpy - INFO - Chain [1] start processing
# 16:49:22 - cmdstanpy - INFO - Chain [1] done processing
# 16:49:22 - cmdstanpy - INFO - Chain [1] start processing
# 16:49:23 - cmdstanpy - INFO - Chain [1] done processing
# 16:49:23 - cmdstanpy - INFO - Chain [1] start processing
# 16:49:23 - cmdstanpy - INFO - Chain [1] done processing
# Master forecast file successfully created and ready for Tableau!

# %%
https://public.tableau.com/views/Globalenergytransitionforecasting/Globalenergytransistion?:language=en-US&publish=yes&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link
